# %% [markdown]
# # 함수

# %%
# 딕셔너리 형태로 함수를 정의
f = {1:2,
    2:4,
    3:6,
    4:8,
    5:10}

# %%
# 앞서 정의한 함수 사용
f[2]
# Out:
# 4

# %%
# 사용자 정의 함수
def f(x):
    return 2*x

x = 10
y = f(x)

print(f'f({x}) = {f(x)}')
# Out:
# f(10) = 20

# %%
# 부호함수: 양수이면 1, 음수이면 -1, 0이면 0
import numpy as np

np.sign(-0.0428), np.sign(0), np.sign(123)
# 출력 형식도 실수와 정수 형태에 맞춰서 내준다!
# Out:
# (-1.0, 0, 1)

# %%
# 각 구간 최대, 최솟값을 포함한 n개의 숫자로 나눠주는 함수
np.linspace(1,5,9)
# Out:
# array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
def f(x):
    return x**3 - 3*x**2 + x
x = np.linspace(-1,3,9)
y = f(x)
y # 하나씩 값을 넣은 전체 결과값을 배열로 출력
# Out:
# array([-5.   , -1.375,  0.   , -0.125, -1.   , -1.875, -2.   , -0.625,
#         3.   ])

# %%
import matplotlib as mpl
mpl.rc('font', family='malgun gothic') #한글 폰트 설정
mpl.rcParams['axes.unicode_minus'] = False # 마이너스 단위 처리
plt.figure(figsize=(10,6))
plt.plot(x, y, 'ro-')
plt.xlim(-2, 4)
plt.title("함수 $f(x) = x^3 - 3x^2 + x$의 그래프")
plt.xlabel("x")
plt.ylabel("y")
plt.xticks(np.arange(-1, 4))
plt.yticks(np.arange(-5, 4))
plt.show()

# %%
# 더 촘촘하게 그려보자. 이건 연속함수의 모양을 지니고 있다.
x = np.linspace(-1,3,400)
y = f(x)
mpl.rc('font', family='malgun gothic') #한글 폰트 설정
mpl.rcParams['axes.unicode_minus'] = False # 마이너스 단위 처리
plt.figure(figsize=(10,6))
plt.plot(x, y, 'ro-')
plt.xlim(-2, 4)
plt.title("함수 $f(x) = x^3 - 3x^2 + x$의 그래프")
plt.xlabel("x")
plt.ylabel("y")
plt.xticks(np.arange(-1, 4))
plt.yticks(np.arange(-5, 4))
plt.show()

# %%
# 평균이 10, 표준편차가 3인 정규분포의 확률밀도함수(pdf)를 그래프로 표현
from scipy import stats
import matplotlib.pyplot as plt

x_range = np.arange(1,20,0.1)
plt.plot(x_range, stats.norm.pdf(x_range, loc=10, scale=3), color='cornflowerblue')
plt.show()

# %%
# 평균 1, 표준편차가 2인 정규분포의 누적분포함수(cdf)
x_range = np.arange(-3,8,0.1)
plt.plot(x_range, stats.norm.cdf(x_range, loc=1, scale=2), color='lightcoral')
plt.show()

# %% [markdown]
# ##### 역함수
#     어떤 함수의 입력/출력 관계와 정반대의 입출력 관계를 갖는 함수
# 원래의 함수에서 x축과 y축이 바뀐 것이므로 y=x가 나타내는 직선(원점을 통과하는 기울기 1인 직선)을 대칭축으로 대칭인 함수의 그래프

# %%
def f1(x):
    return x ** 2

def f1inv(x):
    return np.sqrt(x) # 역함수를 구하는 함수를 만든 건데, 수작업으로.

x = np.linspace(0, 3, 300)
plt.figure(figsize=(10,6))
plt.plot(x, f1(x), "r-", label="함수 $f(x) = x^2$")
plt.plot(x, f1inv(x), "b-.", label="역함수 $f^{-1}(x) = \sqrt{x}$")
plt.plot(x, x, "g--")
plt.axis("equal")
plt.xlim(0, 2)
plt.ylim(0, 2)
plt.legend()
plt.title("역함수의 그래프")
plt.show()

# %% [markdown]
# 아래 과제의 $y=x^2+1$의 역함수를 구해 보자.
# $y=x^2+1$
# $x=\sqrt{y-1}$
# 이제 x와 y의 위치만 바꿔 주면 역함수 완성!
#
#
# $y=f^{-1}(x)=\sqrt{x-1}$

# %%
# [과제] 아래 함수의 역함수를 구하고 그래프로 표현하세요.

def f2(x):
    return (x**2 + 1)

def f2inv(x):
    return np.sqrt(x-1)

x = np.linspace(0, 3, 300)
plt.figure(figsize=(10,6))
plt.plot(x, f2(x), "r-", label="함수 $f(x) = x^2 +1$")
plt.plot(x, f2inv(x), "b-.", label="역함수 $f^{-1}(x) = \sqrt{x-1}$")
plt.plot(x, x, "g--")
plt.axis("equal")
plt.xlim(0, 2)
plt.ylim(0, 2)
plt.legend()
plt.title("역함수의 그래프")
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_7288/3954723137.py:7: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(x-1)

# %% [markdown]
# #### 지수함수
# - 정해진 어떤 값을 입력값으로 거듭제곱하여 출력을 구하는 함수
# - 거듭 제곱을 할 때 아래에 있는 수를 밑이라고 하며
# 밑을 오일러 수 e(약 2.718)로 하여 거듭제곱하는 함수를 지수함수라고 한다.
# - $y=e^x$, y = exp(x) = exp x 로 표시

# %%
# 오일러 상수
np.e
# Out:
# 2.718281828459045

# %%
np.exp(-10), np.exp(-1), np.exp(-0.1), np.exp(0.1), np.exp(1), np.exp(10)
# Out:
# (4.5399929762484854e-05,
#  0.36787944117144233,
#  0.9048374180359595,
#  1.1051709180756477,
#  2.718281828459045,
#  22026.465794806718)

# %%
xx = np.linspace(-2, 2, 100)
yy = np.exp(xx)
plt.figure(figsize=(10,6))
plt.title("지수함수")
plt.plot(xx, yy)
plt.axhline(1, c='r', ls="--")
plt.axhline(0, c='r', ls="--")
plt.axvline(0, c='r', ls="--")
plt.xlabel("$x$")
plt.ylabel("$\exp(x)$")
plt.show()

# %% [markdown]
# #### 로그함수
# e를 거듭제곱하여 특정한 값이 되는 수를 찾을 필요가 있는데 이때 e를 몇 제곱해야 10이라는 값이 될까?
#
#
# e를 2.3025851 거듭제곱하면 10이 된다.
# 따라서, e를 거듭제곱하여 특정한 수 a가 되도록 하는 수를 log a라 표기하고 로그라고 읽는다.

# %%
np.exp(2), np.exp(3)
# Out:
# (7.38905609893065, 20.085536923187668)

# %%
np.log(10), np.exp(2.302585092994046)
# Out:
# (2.302585092994046, 10.000000000000002)

# %%
xx = np.linspace(0.01, 8, 100)
yy = np.log(xx)
plt.figure(figsize=(10,6))
plt.title("로그함수")
plt.plot(xx, yy)
plt.axhline(0, c='r', ls="--")
plt.axvline(0, c='r', ls="--")
plt.axvline(1, c='r', ls="--")
plt.xlabel("$x$")
plt.ylabel("$\log(x)$")
plt.show()

# %%
x = np.linspace(0, 4, 100)
xx = np.linspace(-2, 2, 100)
x0 = np.delete(x, 0) # x에서 인덱스 0번 삭제
y0 = np.log2(x0)
x1 = np.linspace(0, 4, 9)
x2 = np.delete(x1, 0)
y2 = np.log2(x2)
plt.figure(figsize=(8,8))
plt.plot(x0, y0, c='b', label='$y=\log_{2}x$',lw=2)
plt.plot(xx, 2**xx, c='k', label='$y=2^x$',lw=2)
plt.plot([-2,4],[-2,4], linestyle='-.', label='$y=x$', lw=2)
plt.plot([-2,4],[0,0],lw=2,c='k')
plt.plot([0,0],[-2,4],lw=2,c='k')
plt.scatter(x2, y2, s=50, c='b')
plt.scatter(y2, x2, s=30, c='k')
plt.xticks(size=20)
plt.yticks(size=20)
plt.ylim(-2,4)
plt.grid(which='major',linestyle='-',lw=2)
plt.xlabel("$x$", fontsize=18)
plt.ylabel("$y$", fontsize=18)
plt.legend(fontsize=18)
plt.show()

# %% [markdown]
# # 미적분

# %% [markdown]
# ### 미분
#
# 최적화를 하기 위해서는 입력값이 변했을 때 함수의 출력값이 어떻게 달라지는지를 정량적으로 알아야 하며 이러한 과정이 미분이다.
#
# 함수의 그래프상에 있는 한 점을 줌심으로 그래프를 무한히 확대해 보면 그래프의 모양이 직선에 가까워지는데 이때의 기울기를 미분이라고 한다. 이 직선은 같은 점을 기준으로 그린 그래프의 접선과 같다.
#
# 신경망에서 미분의 필요성 : https://gggggeun.tistory.com/120           https://gggggeun.tistory.com/121
#
# 미분 개념 : https://www.youtube.com/watch?v=kMZ3RJEaLE4

# %%
def f(x):
    return x**3 - 3 * x**2 + x

x = np.linspace(-1, 3, 400)
y = f(x)
plt.figure(figsize=(10,6))
plt.plot(x, y)
plt.plot(0, 0, 'ro')
plt.plot(x, x, 'r:')
plt.plot(1, -1, 'go')
plt.plot(x, (3*1**2-6*1+1)*(x-1)-1, 'g--')

plt.xlim(-3.5, 5.5)
plt.ylim(-4, 2)
plt.xticks(np.arange(-3, 6))
plt.yticks(np.arange(-4, 2))

plt.annotate('', xy=(1, 0), xytext=(0, 0), arrowprops=dict(facecolor='gray'))
plt.annotate('', xy=(1, 1), xytext=(1, 0), arrowprops=dict(facecolor='gray'))

plt.annotate('', xy=(2, -1), xytext=(1, -1), arrowprops=dict(facecolor='gray'))
plt.annotate('', xy=(2, -3), xytext=(2, -1), arrowprops=dict(facecolor='gray'))

plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("함수의 기울기")
plt.show()

# %% [markdown]
# 비용 곡선이 아닌 효용 곡선으로 구할 때에는 최댓값을 찾아야 하는 경우도 있다.

# %%
import warnings
warnings.filterwarnings('ignore')
def f(x):
    return(x**3 - x)

plt.figure(figsize=(15, 5))
delta = [2.0, 0.2, 0.01]

x = np.linspace(0.5-delta[0], 0.5+delta[0], 200)
y = f(x)

plt.subplot(131)

plt.ylim(-3.0/8.0-delta[0], -3.0/8.0+delta[0])
plt.xlim(0.5-delta[0], 0.5+delta[0])
plt.plot(x, y, 'b-', lw=1, c='k')
plt.scatter([0.5], [-3.0/8.0])
plt.xlabel('x',fontsize=14)
plt.ylabel('y',fontsize=14)
plt.grid()
plt.title('delta = %.4f' % delta[0], fontsize=14)

x = np.linspace(0.5-delta[1], 0.5+delta[1], 200)
y = f(x)

plt.subplot(132)

plt.ylim(-3.0/8.0-delta[1], -3.0/8.0+delta[1])
plt.xlim(0.5-delta[1], 0.5+delta[1])
plt.plot(x, y, 'b-', lw=1, c='k')
plt.scatter([0.5], [-3.0/8.0])
plt.xlabel('x',fontsize=14)
plt.ylabel('y',fontsize=14)
plt.grid()
plt.title('delta = %.4f' % delta[1], fontsize=14)

x = np.linspace(0.5-delta[2], 0.5+delta[2], 200)
y = f(x)

plt.subplot(133)

plt.ylim(-3.0/8.0-delta[2], -3.0/8.0+delta[2])
plt.xlim(0.5-delta[2], 0.5+delta[2])
plt.plot(x, y, 'b-', lw=1, c='k')
plt.scatter([0.5], [-3.0/8.0])
plt.xlabel('x',fontsize=14)
plt.ylabel('y',fontsize=14)
plt.grid()
plt.title('delta = %.4f' % delta[2], fontsize=14)

plt.show()

# %% [markdown]
# #### 접선의 방정식
#
# - 함수 f(x)에서 x의 값을 dx만큼 변화시켰을 때 f(x)의 변화량 (f(x+dx)-f(x))는 f'(x)dx와 같다.
# - 미분 : y=f(x)라는 그래프상의 점(a,f(a))가 있을 때 그 점에서 그은 접선의 기울기는 f'(a)이며 a에서의 순간 변화율을 의미
# - 적분 : 도함수 f'(x)의 하방 면적은 원 함수 f(x)의 y의 값이다. ex) f(x) = $x^2$

# %%
def f(x):
    return(x**2)
def g(x):
    return(2*x -1)

# x가 1일때의 접선의 방정식 2x -1, 기울기는 1
x = np.linspace(-3, 3, 100)
fig = plt.figure(figsize=(8,8))
plt.scatter([1],[1],c='k')
plt.plot(x, f(x), 'b-', lw=1, c='k')
plt.plot(x, g(x), 'b-', lw=1, c='b')
plt.plot([x.min(), x.max()], [0, 0], lw=2, c='k')
plt.plot([0, 0], [g(x).min(), f(x).max()], lw=2, c='k')
plt.ylim(-1, 3)
plt.xlim(-2, 2)
plt.grid(lw=1)
# plt.tick_params(labelbottom=False, labelleft=False, labelright=False, labeltop=False)
plt.tick_params(color='white')
plt.show()

# %%
# scipy.misc 패키지의 derivative()를 사용하여 기울기 계산

from scipy.misc import derivative

print(derivative(f, 0, dx=1e-6))
print(derivative(f, 1, dx=1e-6))
# Out:
# 0.0
# 2.000000000002

# %%
def g(x):
    return(2*x) 

x = np.linspace(-3, 3, 100)
fig = plt.figure(figsize=(8,8))
plt.plot(x, g(x), 'b-', lw=1, c='b')
plt.plot([x.min(), x.max()], [0, 0], lw=2, c='k')
plt.plot([0, 0], [g(x).min(), f(x).max()], lw=2, c='k')
plt.ylim(-1, 3)
plt.xlim(-2, 2)
plt.grid(lw=1)
# plt.tick_params(labelbottom=False, labelleft=False, labelright=False, labeltop=False)
plt.tick_params(color='white')
plt.show()

# %%
# !pip install sympy
# Out:
# Collecting sympy
#   Downloading sympy-1.10.1-py3-none-any.whl (6.4 MB)
# Collecting mpmath>=0.19
#   Downloading mpmath-1.2.1-py3-none-any.whl (532 kB)
# Installing collected packages: mpmath, sympy
# Successfully installed mpmath-1.2.1 sympy-1.10.1

# %%
# 주피터 노트북 상에서 수학식의 LaTex 표현을 위해 필요한 기능
import sympy
sympy.init_printing(use_latex='mathjax')

# %%
X = sympy.symbols('x')
X
# Out:
# x

# %%
x, y = sympy.symbols('x,y')
f = x**2 + 4*x*y + 4*y**2
f
# Out:
#  2              2
# x  + 4⋅x⋅y + 4⋅y

# %%
# 위의 함수에서 x에 대한 편미분을 구하기 위해서
# diff() 명령어를 이용해 미분한다.
# 이때, 변수와 상수를 구분하기 위해 입력 변수를 별도로 지정해야 함

sympy.diff(f,x) # x에 대해 편미분
# Out:
# 2⋅x + 4⋅y

# %%
# y에 대해 편미분
sympy.diff(f,y)
# Out:
# 4⋅x + 8⋅y

# %% [markdown]
# ### 적분
# - 적분은 미분과 반대되는 개념. 부정적분과 정적분이 있다.
#  - 부정적분은 정확하게 미분과 반대되는 개념. 즉 반 미분이다. 어떤 함수를 미분하여 나온 결과인 도함수라고 가정하고 이 도함수에 대한 미분되기 전의 원래의 함수를 찾는 과정 또는 그 결과를 의미
#  - 정적분은 독립변수 x가 어떤 구간 [a,b] 사이일 때 그 구간에서 함수 f(x)의 값과 수평선(x축)이 이루는 면적을 구하는 행위 혹은 그 값을 의미
#
# 적분의 개념 : https://www.youtube.com/watch?v=kV2j3S5qBm4
#
# 미분과 적분의 관계 : https://www.youtube.com/watch?v=xAAAvj7bmKQ

# %%
x, y = sympy.symbols('x,y')
f = 2*x+y
f
# Out:
# 2⋅x + y

# %%
sympy.integrate(f,x) # y는 상수 취급
# Out:
#  2
# x  + x⋅y

# %%
from matplotlib.patches import Polygon

def f(x):
    return x ** 3 - 3 * x ** 2 + x + 6

a, b = 0, 2
x = np.linspace(a - 0.5, b + 0.5, 50)
y = f(x)

ax = plt.subplot(111)
plt.title("정적분의 예")
plt.plot(x, y, 'r', linewidth=2)
plt.ylim(bottom=0)
ix = np.linspace(a, b)
iy = f(ix)
verts = [(a, 0)] + list(zip(ix, iy)) + [(b, 0)]
poly = Polygon(verts, facecolor='0.9', edgecolor='0.5')
ax.add_patch(poly)
plt.text(0.5 * (a + b), 0.2 * (f(a) + f(b)), r"$\int_a^b f(x)dx$",
         horizontalalignment='center', fontsize=20)
plt.figtext(0.9, 0.05, '$x$')
plt.figtext(0.1, 0.9, '$y$')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.xaxis.set_ticks_position('bottom')
ax.set_xticks((a, b))
ax.set_xticklabels(('$a$', '$b$'))
ax.set_yticks([])
ax.set_xlim(-2, 4)
ax.set_ylim(0, 8)
plt.show()

# %% [markdown]
# ##### 정적분을 구하는 방법
# - sympy 등으로 부정적분을 구한 뒤 미적분학의 기본 정리를 사용하여 푸는 방법
# - 원래 함수의 면적 부분을 실제로 잘게 쪼개어 면적을 근사하게 구하는 수치적분 이용

# %%
x, y = sympy.symbols('x,y')
f = x**3 - 3*x**2 + x + 6
f
# Out:
#  3      2
# x  - 3⋅x  + x + 6

# %%
# 부정적분
F = sympy.integrate(f)
F
# Out:
#  4         2
# x     3   x
# ── - x  + ── + 6⋅x
# 4         2

# %%
# 구해진 미분 전 함수에 정적분 구간을 넣어 값을 계산: subs(), evalf()
(F.subs(x,2)-F.subs(x,0)).evalf()

# 원래의 함수에서 0~2 구간의 그래프 아래 면적이 10이라는 뜻이다.
# Out:
# 10.0000000000000

# %%
# 수치적분
import scipy as sp
def f(x):
    return x**3 - 3*x**2 + x + 6

sp.integrate.quad(f, 0,2)
# Out:
# (10.0, 1.1102230246251565e-13)
