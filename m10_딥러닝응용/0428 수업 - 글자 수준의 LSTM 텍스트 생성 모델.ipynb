# %% [markdown]
# # LSTM으로 텍스트 생성하기
#
# ## 글자 수준의 LSTM 텍스트 생성 모델 구현
#
# 이런 아이디어를 케라스로 구현해 보죠. 먼저 언어 모델을 학습하기 위해 많은 텍스트 데이터가 필요합니다. 위키피디아나 반지의 제왕처럼 아주 큰 텍스트 파일이나 텍스트 파일의 묶음을 사용할 수 있습니다. 이 예에서는 19세기 후반 독일의 철학자 니체의 글을 사용하겠습니다(영어로 번역된 글입니다). 학습할 언어 모델은 일반적인 영어 모델이 아니라 니체의 문체와 특정 주제를 따르는 모델일 것입니다.
#
# https://s3.amazonaws.com/text-datasets/nietzsche.txt

# %%
# 과연 이 모델은 신이 죽었는지 아닌지에 대해 말할 것인가?

from tensorflow.keras import utils
import numpy as np, tensorflow as tf

path = utils.get_file('nietzche.txt',
                      origin = 'https://s3.amazonaws.com/text-datasets/nietzsche.txt')

text = open(path).read().lower() # 가서 보면 알겠지만 중간에 대문자 많이 튀어나옴

print('말뭉치 크기:',len(text))
# Out:
# 말뭉치 크기: 600893

# %%
# 내용 맛보기. 개행 문자와 특문을 처리해야 할 것 같지만 일단 이대로 진행.(문장 부호도 하나의 특징이니까)
text[:300]
# Out:
# 'preface\n\n\nsupposing that truth is a woman--what then? is there not ground\nfor suspecting that all philosophers, in so far as they have been\ndogmatists, have failed to understand women--that the terrible\nseriousness and clumsy importunity with which they have usually paid\ntheir addresses to truth, ha'

# %%
# 60개 글자로 된 시퀀스를 추출. 한 문장 안에 알파벳 60개가 들어 있게끔.
maxlen = 60

# 샘플링은 3글자씩 건너뛰면서 새로운 시퀀스를 샘플링.
# n_gram이 3인 것과 같은 뜻일까?
step = 3

sentence = [] # 시퀀스는 여기 리스트에
target = []   # 해당 시퀀스 다음 글자는 이 리스트에

for i in range(0, len(text)-maxlen, step): # 0에서 600,833까지. 마지막 시퀀스가 60글자인 걸 감안해야지.
  sentence.append(text[i:i+maxlen])
  target.append(text[i+maxlen])

print('시퀀스 총 개수:', len(sentence))
print(sentence[:2])
# Out:
# 시퀀스 총 개수: 200278
# ['preface\n\n\nsupposing that truth is a woman--what then? is the', 'face\n\n\nsupposing that truth is a woman--what then? is there ']

# %%
import warnings; warnings.filterwarnings('ignore')

# 말뭉치에서 고유한 글자를 담은 리스트. 알파벳 26자와 특문 등이 들어갈 것이다.
char = sorted(list(set(text)))
print('고유한 글자 수:',len(char))

# 고유 글자와 해당 글자의 인덱스를 딕셔너리화
char_dict = dict((character, char.index(character)) for character in char)

# 원-핫 인코딩
x = np.zeros((len(sentence), maxlen, len(char)), dtype=np.bool) # boolean 타입은 true or false의 2가지 값만 가진다 했다.
y = np.zeros((len(sentence), len(char)), dtype=np.bool)

for i, sen in enumerate(sentence):
  for t, ch in enumerate(sen):
    x[i, t, char_dict[ch]] = 1
  y[i, char_dict[target[i]]] = 1
# Out:
# 고유한 글자 수: 57

# %%
# 네트워크 구성
from tensorflow.keras import layers, models

model = models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(char))))
model.add(layers.Dense(len(char),activation='softmax'))

# 위의 모델이 무슨 말이냐 하면, 시퀀스와 그 이후 오는 글자를 학습한 후에
# 저 고유 글자들 중에서 어떤 글자가 다음에 올지 그 확률이 제일 높은 걸
# 다음 글자로 선정한다는 것임.
# 이때 '소프트맥스 온도'라는 개념이 사용되는데, 엔트로피의 높낮이를 바꾸어 무작위성에 차이를 둘 수 있음
# 뻔한 글자가 나올 수도, 창의적인 글자가 나올 수도 있게.

model.compile(optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.01),
              loss='categorical_crossentropy')
# 여기선 뭐 분류하고 그런 거 아니라서 정확도 측정은 안 해도 된다. 정답이 없으니까.

# %% [markdown]
# ## 언어 모델 훈련과 샘플링
#
# 훈련된 모델과 시드로 쓰일 간단한 텍스트가 주어지면 다음과 같이 반복하여 새로운 텍스트를 생성할 수 있습니다.
#
# 1.	지금까지 생성된 텍스트를 주입하여 모델에서 다음 글자에 대한 확률 분포를 뽑습니다.
# 2.	특정 온도로 이 확률 분포의 가중치를 조정합니다.
# 3.	가중치가 조정된 분포에서 무작위로 새로운 글자를 샘플링합니다.
# 4.	새로운 글자를 생성된 텍스트의 끝에 추가합니다.
#
# 다음 코드는 모델에서 나온 원본 확률 분포의 가중치를 조정하고 새로운 글자의 인덱스를 추출합니다(샘플링 함수입니다):

# %% [markdown]
# 밑이 자연상수 e인 지수함수(e^x)의 그래프<br>
# https://wooono.tistory.com/214
#
# Python Numpy.log()-로그 <br>
# https://www.delftstack.com/ko/api/numpy/python-numpy-log/

# %%
# 예측이 주어졌을 때 새로운 글자를 샘플링하는 함수
def sample(pred, temperature=1.0):
  pred = np.asarray(pred).astype('float64')
  pred = np.log(pred)/temperature
  exp_pred = np.exp(pred)
  pred = exp_pred / np.sum(exp_pred)
  prob = np.random.multinomial(1, pred, 1)
  return np.argmax(prob)

# %% [markdown]
# 마지막으로 다음 반복문은 반복적으로 훈련하고 텍스트를 생성합니다. 에포크마다 학습이 끝난 후 여러가지 온도를 사용해 텍스트를 생성합니다. 이렇게 하면 모델이 수렴하면서 생성된 텍스트가 어떻게 진화하는지 볼 수 있습니다. 온도가 샘플링 전략에 미치는 영향도 보여 줍니다.

# %%
import random
import sys

random.seed(42)
start_index = random.randint(0, len(text) - maxlen - 1)

for epoch in range(1, 60):
    print('학습할 에포크 횟수:', epoch)
    # 매 1번씩 새로이 학습. 이를 총 60번
    model.fit(x, y, batch_size=128, epochs=1)

    # 바탕이 될 시드 텍스트는 무작위로 선택
    seed_text = text[start_index: start_index + maxlen]
    print('--- 시드 텍스트: "' + seed_text + '"')

    # 소프트맥스 온도가 낮을수록 뻔하지만 논리적이고, 높을수록 참신하고 못 알아들을 말이 나온다.
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ 온도:', temperature)
        generated_text = seed_text
        sys.stdout.write(generated_text)

        # 시드 텍스트로부터 400개의 글자를 덧붙일 예정
        for i in range(400):
            # 지금까지 생성된 글자를 원-핫 인코딩
            sampled = np.zeros((1, maxlen, len(char)))
            for t, character in enumerate(generated_text):
                sampled[0, t, char_dict[character]] = 1.

            # 다음 글자를 샘플링해 가면서 해당 온도에 맞는 문장을 붙여 출력
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = char[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# 학습할 에포크 횟수: 1
# 1565/1565 [==============================] - 229s 145ms/step - loss: 1.9730
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same and the sensister the spirit the sengution with the sensistance the senguth and the sensistance of the sensistance the sengust the seneres and the sengute the sengute the sensister and the sensister and the spirit in the sensister the sengured to the sengute and the sensust the sengute the passions and the senguth and the spirits the sengute and concestion and striggt in the senguth the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for know, the concernte it everything the conscions of the most the feal to the longer and all the moral man as all the domand the sensicts of the spirits of the conscious to in restrotions of the religious for with it stander as the prich the belief the this sought and confurse the asserned with the coural the sease the distances in the moral prisemptes of the posic the
# the seneres the is others lo
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for extmil the
# ration for ine"s, foreved
# lore in over religious aldo gectain to withen ppised ea
# " presamed and mustonate  f st truthmer
# than vactiay, factires of a great frement that it has howevers
# supming a dekmatesious has is suminally tise, that, and condection, and vere its appon. notring the spirits and has tarcomantomines imprestuctian
# late one alterouse, we haw
# therevere the would event and
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forle assiwine desistaint man ess-mitary fgrment "in, grounce as even in libe the
# bolitiass: for supersfily that
# furcalie, its poorinical, sitath curtences hand
# cenars i 1fuchd!
# unj wich by allemand
# prifediarise all engliers
# knows, bycomeness, that no the selition!
#
# fmompties. wey in otund, to
# crayfe ouray manjuds (nee surty this.
# the blend youse one now with sughtly e aseuvenage to when the
# compurs
# 학습할 에포크 횟수: 2
# 1565/1565 [==============================] - 230s 147ms/step - loss: 1.6182
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the spirit of the spirit of the spirit of the spirit of the spirits of the spirits of the spirit, and something the spirit of the sould to the sention of the spirit of the spirit, the spirit of the sould in the spirit of the spirit of the commanding and progress of the spirits of the promised that the sense of the spirit and the spirit, in one in the spirits of the spirit, the spirit of the spir
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the spirits the most believe be its nother the most profunations of the spirit of incentant, and this soughty of every desirtains and conscience, and to the relarily of the believe in the spirit, in its regard, in her former from the beganding and most presentions without the delight the same the believe of a scrong has to in its be most conscience the culture, and but one in the souted the comm
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through formest here ungenerations-why
# anew to
# saintesbly, eved!--it of a wound hansungem
# esse daver spirits, it could in folly foring and one, psecolol from
# carnory,
# what gence that an agene, wise ronces, "the gident berious moganned believe, woman" (needs of the denalowige,
# untenved intilied and hisis contathord indats degree our comes in zire only with as juded, but the doy the regalded" inberious is any
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fore,"ary with sigil
# man
# badse.=
# in at baib, ourselvess,
# but fals
# rendenve
# hagndation of the
# romensibme onry, who misinally that all disgrdant, the bit. let the dillibles,
# nobaner, but -mo"thering philosophsila! orefgrite."""--if and griatetanncoun the
# weraver; very
# clean, one hasiond.
# under olcaval
# superblegis conscience,
# confercal's a fathesment, practority indald as to the less
# canly grue.
#
# e
# mad
# 학습할 에포크 횟수: 3
# 1565/1565 [==============================] - 229s 146ms/step - loss: 1.5302
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the strength and the sense of the sense of the sense of the perhaps an all the strength and the sense of the sense of the serious of the sense of the most personal and it is also an interpoding of the sense of the sense of the sense of the sense of the soul and the sense of the philosophy of the sensial without the sense of the sense of the entiment of the soul and without the philo
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the disposition of they have coulses they has for the sensial being their day of the mortariabled, and the stooking of one's experience, and the relation of
# the seemary-toes and comprehinting it causes they "tere of the perhaps and still the sense are consequently
# the thought of the have they are pleasure and good to be not at end and also a perhaps manifests that their same and the conterpours
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for the
# that the
# happen utmginous good resulted internary borase and evil
# shight deartedness of thren it destratyin adypact to father is, of its bactically instinct tervers and
#  the
# leerness. the
# exister eme, that some habit, than and been perhaps
# be bad light of
# given bedight the first
# the world ands esquedion of spirition toneadeness, cainities, laboveroused.--we was mordinagians they certainty ev
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forwerle?
# beforremd. 1evivious and rekers cejtir own tederdedly an it isdntts though to
# what gebve an
# i belief.
# anythen than last dimation ar
# "scienting,
# that
# cenied
# habity (
# one, their qual. be unsciplisely as ag" bettheep!m so betpopusegide, virtueger, a  sonont ime lopeablloward: biting tocup] another
# of gial! perhaps in 'rexiration who knowledy or roys of idearary". what
# has name!
# ygo man to puc
# 학습할 에포크 횟수: 4
# 1565/1565 [==============================] - 230s 147ms/step - loss: 1.4832
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the subtle the same the sense of the same called the sense of the same the sense of the same whole of the same the subtle the subtle the subtle the problems of the same the consequently in the sense of the subtle the same interponate and such a promition of the many in the sense of the soul and the sense of the subtle of the subtle of the same the same the experience of the subtle the sense of t
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the
# sense of every scain the subttst of the element of the believed the hard and destrumy of the onot the "many the every seems the learnes as a god away, he in the subtter of the world in the fallent the standard, and and very sight. one has been in the soul of the such an according the attains the should little the ally, but every be more interpretation and the very a philosophers of the suppo
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for their instancts of it extritation callen or in abitions in there, and life. it is the preacition the standad's be,
# like
# courage or of the pate of the sort in lone that it  what all
# in our itricality in it. in the
# freedom.--it is for culture pilility." consequent
# of learnel -who pilling, from mankin say.
# unyster stoeks to sure sohillection: i have been storge, their onaus ning violing when or "p
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for prodections are unintaility expitie she more
# seoulually triblecality--cronted-then liture eversts of highjer receanneusys" love out" langurable, we
# has , we rable terrigh aory-flitt in christious ess. thos
# consciously not.--sjecting,
# be christran developmence do cunculing their matters. dight idigate
# man in the joried rele to viewlowry civelte necessary; good capality:
#     every
# assetimer-this
# 학습할 에포크 횟수: 5
# 1565/1565 [==============================] - 227s 145ms/step - loss: 1.4511
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sould to the presentiment in the statis to be the same to the same the same and the structives to the same the sense of the structives and the subjues of the same the same and sould in the extrance of the same and the same the strets" and the same and the same the sould to the sould to the same the spirit, and the sould to the same the same the sould to the same the scientific in the case of
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for one by the measity of the word of the deed how to the hand therefore in any conscience and
# to this distrust and fact of the spirit of the spiritual
# such a politics, and command of the strets; the origin of the extrance the tarting with one and and instincts. the comparity of the scientific in the enautifiers indelications with the aristocration, and they laws, and to cannot the ages of the case
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for un: it
# were forief of himder, i1 wants how circumstance, or make earlicties his lay looks crece-euracted a man have saifts tiates nature to prais, i he seemed by presude vidoract w"omanes and presence, they already called to the "immen of diskantiverifical espress but that
# "is dare if
# the commens speciality,s and
# in say.
#
# 18
# thing in accounated without sing in the cholcarity inclosisof not be be
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forwardly knovreagiok! bitjee with here man can share imitated by so
# the character, froe nomonks, with dististhesleasing"; for on sometenean pleasuce of goly immentex its are wull heriby hrights." vrow jumy," ifner.
#
# chiuising,
# as scauusaa, as it is pans.ingeness and ridel.=--and by can
# se fle. neverwage of future of
# innequally anbicquosicar batreely peryon nature to oppise of decial.
# the
# my bawe as
# 학습할 에포크 횟수: 6
# 1565/1565 [==============================] - 229s 147ms/step - loss: 1.4296
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the good and the the sense of the depersoness of the great and the sense of the great in the great and the sense of the same art of the good and the sense of the same man and the sense of the sense of the great and the contracks of the really the sense of the means of the good and the world of the far as the german to the german and art of the world of the same the man and present a
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for present of the things when we aromant them of the more of the same expression and the germans and accounticism of the most will the greater of distingual our opinion of the same whole he must a men of the great who have not will to the vers and progrosity and there are, the development of the says of the same is it
# existence of the present the case of superstition and correscally and its were an
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for man, becaparitusation youl:
# betrean at all their delicate that such a bad tiundle is purpose mencible besome that the harmed, prejudical trusisable and must carry which do may beinisy of plriors and parts they was only theuration it noimed the kindwies--and
# perhapn constituded to that a thereby non-also "for altypial philosophy, and
# adoys
# less purposed
# spirit it, her-and indere on god itself
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for their
# .=ysuling the unkenicant,--as
# they could if me are its amox? we longs of our knowledge's religion, spend of from efters in the better--superminism of this, blaliff in boche onity of tole ma knott; we into
# that but haves rea.h it murtimes great by regrohept be only inspire oke promoom tome could witainasmed afterlating and prayt to the cocristing these its abofts, as , it other experience t
# 학습할 에포크 횟수: 7
# 1565/1565 [==============================] - 230s 147ms/step - loss: 1.4101
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through form of the suppositions of the spirit of the does not and sense and the spirit of the action of the spirit the supposition of the concerning the spirit and concerning the spirit and spirit to the spirit and concerning the concerning the spirit and spirit and superficual and spirit and concerning the concerning the spirit and superficiated to the concerning the spirit and concerning the spirit and s
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the having to sense of the concerning all the false, and surplenders of the lack and standpointly consequently of the artists in the most time of the faculshines to distrust first many the geniuse in the attains into the very concerning the belief the enlightences to be a popular with the more in its or conscience of the spirit and to the states of the one of the one's
# asceteriness of the opposi
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for the very molothers oneself decisfied and workt" spakinism
# and ungreating structure,
# have result thember, therefore is an end." of has, ; on the onient in such blamned
# so
# of
# exposiulinesshines now with a smansce appearence of ptilly
# should not. a duther heart,
# at
# in the wagarity: all
# a docteroricm to its time timish-rarow
# of
# vivised with the "unpersinians or rare, every predigmet it funeament. sh
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for an one's question--nermorism.juts--forve--considerszous quire false omer--would be possible, acts makem and
# esciently, what mights
# be
# namelness--let bees" the self "wayse havy
# does it demur assumentherticians)--: the goodsy, reverence developing the have sore
# teal be suppotable, a dringured, also a hasingly to be were eassy here sought
# of o
# rulf, of wished
# bgiusn,y--
# cinctiin."
#
# asy mole excette
# 학습할 에포크 횟수: 8
# 1565/1565 [==============================] - 231s 148ms/step - loss: 1.3975
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through formerly of the sense of the strength in the fact of the fact to the conscience of the far a complete the subject the present in the consequently the man and the most present in the good and the fact the most present one with a man with the sense of the man of the fact of respect to the interesting of the truth and the most pressions and the interest of the sense of the consequently the strength in
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for every the world of the fact of the self-delumanter, which is such a facts a man and free spiritual sense in the god and such a strength in the germans in the falsical with the even himself and such present in placies the
# greatest and weach, and in the self-carners of here in the entire of the
# comparison and again and man and strength to this processing for the general property for its at the fac
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through force doy thorsing,
# onhe--it; with
# all
# naths becausa--in these partory, awary
# and perceiving himself, at the venly-menief and fbine, suummound of goding and
# lands and spirine by summanking. the same
# stranger, communeded, though mask
# it what) him botren that each, with recipration,
# and this sees that his strmnothy, of mankind these moralities
# and unamered by origrest with the present
# could pthem lirn
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through formerly
# old far brandanical work dood with ideak halwdrilish-purioritatoun vice, uneftear, abatining yeak
# views dinglises too
# "period: self m all erehs of souls. at prace in everything und will all the
# dero'st of
# felliand. to ye seemetwicalized,
# ana "virblence.
#
#
#
#
# hhaps view may hostryer o-meversim triunfund and plain xeek intlacs, be ao
# mesting and class of, to latter etheary endomed daring, of s
# 학습할 에포크 횟수: 9
# 1565/1565 [==============================] - 229s 146ms/step - loss: 1.3861
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through formerly and property in the complease the concerning the present intellectual proposition of the present the consequently concerning the sense of the same antigon and an anti-can the sense of the same of the personal and the sense of the sense and the consequently the same of the same as a sense and allow it is the personal and the constitutes that is a perhaps the sense that is a perhaps the sense
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through formuly has hitherto of all the sense that we soul has something for the brutact and consider to the contradictly and the tense, in atterious of the sense of the religion of the world and accordancy, and pleasured the proy to the valuation as a that the contemplation and self-contempting that it is a souls that is not the derence to far to pited on the sense of the
# distrust of the sign that it is in
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for anyonism," in
# preuagered freemous sport in his neverturiousoly another, man who recame or a comountery--expedurence, the
# old are dream delwlaner, will that the demand to circling well extramy. both,
# form of dutains nature, the races of how cholly? viewed, man to, even the incorponentautes noing victort, as hander god; it is is the
# except of expeduded. it is, seel are the god tale the "godoquanne
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through formed"zed as goal owing exersence--that is the idea proposition headt usponsopitence--fralre, or bad singpess rishelv! by historivment my woil to nungous harpineoty are amorance s"y; however, and kneution tod impulse and motivnencacus, swence for supeed him an feclent stortl ape
# anvess of space, he verytrous teaching disconduring the cefiedures of thick as that the enbude. the is---""sorrewhd art a
# 학습할 에포크 횟수: 10
# 1565/1565 [==============================] - 229s 146ms/step - loss: 1.3746
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through formerly that is the same is not a soul of the sense of the germans and the same are the same are the same in the same are the sense of the germans of the same are the same soul of the same are the sense of the manifest of the same are and distingut the same the sense and soul of the same was a stands of the same is the sense of the same soul of the god, as a soul of the sense of the sense of the sa
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through formerly as a soul is also whose as a god like experience of which the distance of the same as good of the same whole course to be best interropunt, so friendoking which will be more are to be soul is not a more to be instincts, as the germans of the sense and formerly the sense of the one is the interest in their far too much of the sense of the super to be not as a soul of the most philosophy, whi
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through formerly,
# for philosophy that is europe. a disintain nowadays. hence a
# dcong, "the holosop souncection, the emouracled fording of
# henges, christianity, as his now, nor strange, sundues of certain; conversion of reverence of man might be bondom realth, master, and grogmes is to the gal
# now hie also propositudis; to rear refires, foothovely finall
# to real to but is not
# seem to put develowilically tha
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through formerly as a foin listed--and wiemd, so "corrance, if every
# geneun
# habping, that is not okinishes, whrorver occasivality as as eventles
# to progod: for throughes, possession, which that is even werplated booding
# cuso that onesel-rignation, foogentves. a po those
# forhaldry toot
# have so o. -unother;
# but of that he gand has "them which it is
# gown; nay thanrr-ages by tepy; it was a strongch of the evolu
# 학습할 에포크 횟수: 11
# 1565/1565 [==============================] - 232s 148ms/step - loss: 1.3676
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the man and spirit of the presence of the spirit of the consideration of the strong and belief that the promise of the struggle to the condition of the spirit to the end in the presence of the spirit with the presence of the presence of the promise of the spirit to the stronger and brought to the consideration of the strong to the superficial and all the expressing to the expressing to the prese
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through forms which does the epoble to the brought of the man to resenting and belief of the man and conducian which is a world of the men as the able to the complexite in the asseriation of the highest blend of the more proceeding the explamation of a histery and scientific man an of the spirits of the sense of the significance, an interrogation of the desirable to the romance of the part of the reading of
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through follow a worfor, and how keep an exerctment. but however of the
# catrim and dora, human nothing of the mingnonure on in which we have--is the train unilvebof
# alle of the ratering to progress of faust there each rases
# and somelily of retersting all most previ"opial does more explaining of everyf the world if out of humanities, obleminy backing
# first morals
# are elert not to know free
# spiral, the so ger
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fool"; not perhach when           from turntis--teicers
# he may be last forepourally. so might they hearly sour took itagabses to do alwating specially a pets.ce smill, the intellectments the "ress!mp
# =the fullkwiness asourisuliveits that how god' sverness his
# souls., that is welled se rifite sty.chring.
# her to preeccs of in there ofdeed and very icet wolleused respect,--of us. it has disclep in the
# 학습할 에포크 횟수: 12
# 1565/1565 [==============================] - 232s 148ms/step - loss: 1.3590
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the present that the present and the sense of the fact that the entire of the reason of the same the sense of the present in the self-contemplated and the self-presset in the present the same the self-pressent, and the same the moral present and the self-contemplated to the expression of the present the fact that the fact that the contentive and the same the present and superiority
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through forees and a determite of each better to be the and to the questions of the same things that the soul of the same conterplates in different and moral sharling experience of the christian science himself. there is not in the self-contrast of the way to the same consequently music of a world and the consequently concealing the unders. as to the great in regarded as a scave with our and consequently fo
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for eknored. so, without now ammulue to in advantale wes", and without no
# undengr.
# the gratefulents
# in order
# the chellexy of thought; henessele bedow whom the manger of a principal good and do not best, it has of their egoisuls, as first,
# and pmeterise without only gratification and his footnow.--an out his virtue which the
# gives religion
# and men: for instance, for man
# is prace is near independent h
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forers-, when
# is communitic, imonately, there for an men seemene, power.
#
# 1ot
# a upon to they may domin
# against betout that,
# 2iure-witism.-the provaes; a facts on her coance through a part-formul disturble in
# the perlothe; a perfectlns, forhsing arbility: that thin.nis with a valuism of things befoous is, if teme:
# great fore: ie case zew.
#
# lalor to gurable-suises
# and class, the
# to speaking will bende
# 학습할 에포크 횟수: 13
# 1565/1565 [==============================] - 229s 146ms/step - loss: 1.3525
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through former and distasion and desires and soul as a standard of the same assimiation of the subject and all the same such an antiqoing the same as a constantly and all the solentive and soul as a state of the suffering of the subject and sublim to the surmounds and surmul the same all the same are all the same all the suffering the same as a standard of the same are all the same as the sublimity and dist
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through formally mankind, and superiority the spirit imaginetey and stages and will so says the act and age to him the present
# deserves all the most profound. the suffering that what is a rest thing almost one and thing in the consequently and distrust, their strength standard that another had in being the spirit with the sole of the condition and the subjection and distinction of the laster of morality of
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through formstownest vanity--old from the nequltives to have the three said nothing the right--oneself. but can, and with the disparagic tawardord rained. everything then feel as why
# dellow of subruerver
# inexiration: you wholy the elevation of by new persince, looke
# and
# a chylactive and pitorse) injurity
# problem-blises loes--a scantical
# knowledge at all from which the consident himkelfulty?), as a drinded s
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for most impussible for them to the sourdest is to the errore; as modern fronting, sn same optration of, longarablep. uncondidity
# with some its withtless. the humaty, a vallent"ness, lumality, is bdround in
# the
# shauter and i
# this phulture) wishop soothingly wars than
# they sheminlr-bout? wull indiddence ideas, it cansnomarkais, can bird, as it for elegaask d systainor. dreivenessly, losed as their en
# 학습할 에포크 횟수: 14
# 1565/1565 [==============================] - 230s 147ms/step - loss: 1.3456
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same time and the habit of the same attester and the same time in the same allowands and distrust of the same allowands and the contradiction of the same time the same accoriation of the same time and the conscience of the same attains and allowed the communities of the spirit the same are the same also the consideres the action of the same time and sacrifice of the same time and the action
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for our present speak of the logical world that it is not a distrust and in the things consistence of the communitial subtle with in the same time who allowed of the spirit in the away to the suffers of the himself, and desires. we have hitherto be in the being to be his the sense of the world that it is say the act the prevailed, it is conception of the communities of the present in the soul of the
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foreg! on
# testerings, that
# i have priviladial
# very enough of the "brangly more prowens"istfulely dignally true instent the worst, spowly effect in this, grown unity in everything it
# has fast dangerous bands--only our wit nectisustation are not no retasis for heart for which way of our again-concepsitation of other the talk is mef, for seeking "without plaisation of thing has
# to farruble, possesses f
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for, by blis," sufrent'" divineod as, he evil duen
# under
# habitf is delight
# belief onmentionating,s easious-vitbuoc-dance of humanity hecoumful that the strength. what we have there is too--moralities fyst dinglunch. formul healthory in us human rase,
# is
# solitute, the may by unwhole, before different himself pitually, i li. doy to string, lofe, is the more  revardabse-belongring evented mistaking all
# 학습할 에포크 횟수: 15
# 1565/1565 [==============================] - 233s 149ms/step - loss: 1.3402
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through former and the man by the philosophers of the states of the standard to be an antiouss and the precisely and the decluse of the more artists of the philosophers of the persons and the self-considered the manifests of the manifests of the precisely the states of the persons and the present the the man by the problem and strong and strength and the states of the manifests of the man because in the sta
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through former and the value of the the mangitations, which their in the practice and complibed the sufficient and there are dening the most states
# (when has been strength in the standard the lower of the somentions of the artists the whole even the recognizing the states of the distrust of the advantable therefore the one there are in the independent consequently the belief, and indectually unevery general
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forver though allow."
#
# 1i
# to be men was formers
# their a,
# it loast so
# "principity metaphysice is artistic furmanate harded, in predifficultal men are of sacrifies
# of virtues-ased assuming the man, still waitlary right, be
# mi an
# immecial of boly of christians, back consative only ona
# sahvess,
# whatever?
# liket of this word,
# and when to them: one regard himself. the abaduci"--who
# inculted grows
# theltists
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fordinariea? concrust,
# and you, betreally anterect the being noble and ultlost, faths of
# propositious reverence, on one's positious physiologicila valuately
# and middly by the fulthey:-then necessant ingrountordix,
# nemable serivitious; he how german by his conversting
# as unancictifiedbing
# of
# long--the german, that he is very widdly be 'wht many each and
# by pain
# far in are," the, sqpecerate," the stre
# 학습할 에포크 횟수: 16
# 1565/1565 [==============================] - 233s 149ms/step - loss: 1.3363
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through formult, the superite and successful and the same acts of the fact is to the same artistic and successful and man and successful in the master and sure and the superiority of the fact is the same artistic from the most decided to the moral and and and consists and and successful and successful of the master and successful and some and disposing and all the moral and man some to the suffering the sam
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through former are the german of every surploring that the causan feelings, and
# a personal and the comparison of the soul when to the train in the same way there is a man is a scientific of morality, and the struggle to shore of the greatest the fact, in the unconsciented to a present, the german constraint and society, and let under the religion and morality that i live sensia of the attelling self-essenti
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through form that upon heres:--thich and moral,
# which mas" to make them;--it is influencenory and look
# gen, and as a critces,
# promposses first. much forgut we ho the
# serts, is more as the most men of which
# thes, and
# great brard presence of himefic. then othersely on the physice and,
# in sort of criticihyes
# sures
# ruldly
# to
# venliters and finere--partly to serce, here
# whatever man new ideats, seems for ones in
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through follow-the, and
# and mirrous. i--fresg an acristing or named, would sepy taken
# and literous
# will afford."
#
# 113. vere egoististiin," cause of the world
# from
# to ventivis
# consciented an amplead womanwish? thens were
# highestly doublen
# of in everyeon the last
# "god. she upon areld pretimitions of
# anyone the !vi(titude. it is fully frieht urupow that to a will of eortly, the
# gental whose maked, the badtics,
# 학습할 에포크 횟수: 17
# 1565/1565 [==============================] - 232s 148ms/step - loss: 1.3298
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through former and state of the spirit of a state of the spirit of the realling the constantly and best of the spirit in the same antiqueition of the suffering of the stronger of the strange the spirit of the soul as a distrustfur of the same state of the spirit of the state of such a more state of the spirit of the strange in the suffering of the predicated and the spirit of the state of the conditions of
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through forer of the spirit of the most individual and language, and his far again the instance
# in the reading with the belief of the philosophers to be now at all this is any lights and the subjugeration of the comparately
# the love of the free spirits of the value, or more will to conscience of the first in the higher and individual and regard to the common in the world and intellectually and still intelle
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through founder deceively properse how daisten and distend any in!queh, whence is
# made its philosophy for state of a blacking
# loars of the christianal srobar; prection,d or not be hhisterie
# upon the traiced can should to bringer in mysticg of one's a"ble assahy shot endose, for a "free the remoteration to lates a depervaling wather the spiriticble, his a, a
# home right,
# endoes.
#
#
# =isting constantly ares"--or
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for
# three typicanism knows which in.fer--it ises which the affemplles so said in their ton-le.doculd bad bey wayo for exchalking the men. it rands; we deturt; but withouttone, philosoghicately a succete at opten, good, "i,
# rejugre totes,
# cerement underseys; a peoples as ifterd." to arougr war imporaton as well--he they has arounable, necessarigiousnes apprearation in wordel and wit
# cafties appearty
# 학습할 에포크 횟수: 18
# 1565/1565 [==============================] - 232s 148ms/step - loss: 1.3259
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through former and the antious and called by the same man in the most the same the superiority of the same the presentimentally and the spirit of the sublime and man who are the man and strange, and the man and all the presentimest and something because the man in the superiority of the superiority of the spirit of the present the strength and the presentimest and conscious of the superiority of the present
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for example to be an and basis and take the happiness, and in the popular believe has been man, and constant untrans of the partial strict cannot be all the charactory, it is too the more presentable and a properation of the "great, that in which out of the man and in the stands and regards to communith and the moral to has been cultured to present in the present constitute canorative and which is n
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through former flort, that de greater people
# falp; -a virtuous, there itself purely
# attentive
# our prefers of,
# an authore men to
# poot even one
# , much canbil things estimate and problem of
# the general weakness tray must wacked. also gives it more further of its all the premations with that man gave as neared and but restrain of the exception, that the very history; learned by solitude
# onge
# "skenim on the till
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through form of hypour,
# poobt being eblips of teg; i for
# swandsbeifors when a readward lowe-ger-babbadoy, swelldnimation part, bacy it!
# queites, every.
#
# 17her: thuo; that onzarbical prhiske
# deeging: and the im of the life. state or am" and thinglishm,
# for the beaniness: valu
# swign them a waken the massicism of this histuus language, a having has
# besines is "bging and other
# comvaly pain, the whoplieness"xing
# 학습할 에포크 횟수: 19
# 1565/1565 [==============================] - 234s 149ms/step - loss: 1.3218
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through former and discovered to the superity and such a states and the condition of the superity and the superity and the art and consequently belief that it is a superise the superity and such a many the superity and moral and always all the same the suffering of the strength as the strengtibility of the problem of the superity and the sure and the soul of the superisccion of the surmought the moral as ou
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through formation to it was felt in which
# the religions and deceives and the strengtibility of the moral self-confusion
# and called question of such a sunders, and controls of wishes to repulsed without proper one of the beliefiers which the suffering, and the man of the more more of the end, and the stronger, and in it and interestiom of the supposition of entire in the more disposed. the german satisfactio
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for, and in
# christian. that sympathom it. it is no distusticilnen
# since in such an education, ease so districtiving suffer,"
# but, appeared, says are or he tradents. "to stands the mind
# was gutbed into
# others
# pover momentless from it wast and
# even they pare
# sinceis of simply of its time--that which this kingpress of human it.
#
#
#                an
# quality. they say, it we personal presen specially"
# in
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for,
# heistly. seethom grtatis. this repaited to folly
# men appetores, : os an own descrution as crust of others or it is that a nain there valiation of them which we know perceiving
# than
# would been noe any oodnical of
# simition!
# as they "praise and for the mals, his clear and his ritively, rate no under the youth--is pahing more former,
# and alsoed"--he cases self duties timility is
# word, who lianling,
# 학습할 에포크 횟수: 20
# 1565/1565 [==============================] - 233s 149ms/step - loss: 1.3184
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through formation of the world and the super-again the fact is the considerations of the commanding and the same are the sour as a man of the super-again to the consideration of the super-really an attempt and the fact that the same are the present the super-sufficiently and the fact that the same and the fact of the man of the more and super-can be problems of the present of the same amount of the super-ag
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through former what the profound the suffer). and the fact himself to the are in the masters. and the reason that the consequently perhaps an are so the sense of his superstition is also to askerness of all the fact to the moral mischecolly in the same ackions of the famility and the man as the suspicion to have so the away to consequently the reason of presence of falseh.
#
#
# 14
#
# =young the moral badness, an
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through former and puilolous,
# snaled and pain and it is prefish permiss and the massasses with respect to sonon it hand also, in the voous, the kind, and prefilited made also, and obstions are present itself. could it corracks instince of endiminaice, all dellus, and after
# pain,--in the course of potal, but the mystege," the foirlent and duty, who will, in it is develop in account
# upon their scarifice charm
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forlist"; and but ever
# day, frabitist sunclied, well doevely, we have us this guty nancel,
# the object, has cereme on being love obelitiess"" and the wids rankness of the mereally sign on the
# ones: go this way patrves";--the most every path of fil but bued--wtrange? if that their religions, of infess ebrould linds with dangerouse necessary of whom all antiquitudm one of reever) bad alfeasm by the her
# 학습할 에포크 횟수: 21
# 1565/1565 [==============================] - 232s 148ms/step - loss: 1.3138
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same which the more spirit is alle for the subject the man of the same are not the same alternation of the same are not to the morality of the strength and the stronger of the same are in the same whole the man is the sense of the same alternation of the soul that the same are not to the same things that it is a same things and whole as a strong and the subjection of the suffering and sensit
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the aspections of which is not one will to all things one will with the faith-it is to be distrust of the sense of the senses as himself allowing which the stronger the same another things that
# the will to really nons thinking religions and prevails the strength and subject itself that the all his strivestate himself is being strong of the same is alle feeling of the gradualle
# and finds and allo
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for the fear from chate, whodly aristophase of suche"coury and interprety at this
# desires), to lank of the results on think imounters" of the "sible thy nevergery eneung foo-personal interknuss. are the new:f the signing that in all dove with the barbidity, of thing in
# the let us "pride man willingful by companity rearge, more he is
# sacring iard canising accocqudeged can fort, not plicile, there is
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forme-welly its is frequentlys that to unmest that effect revenge sabing would galis condition and beginnifg of without our
# philososy, to think of its fack-taken greb"ds and, anmars, when is gam there remaing.t
# deriving that a say
# of his abjutt of wedom with egoismsal
# beautiflos, namely: here youth (involtep.
#
#
# 1fantantt.=--the case of delifers nothing idnamety than this belief, bholes of
# vilers? it
# 학습할 에포크 횟수: 22
# 1565/1565 [==============================] - 239s 153ms/step - loss: 1.3098
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through forms of the same spirit and the same the conscience and the fact the same artist and the subject and disturbed there is a man lower the consequences, and belief themselves the sense of the same artist and surmound the consequences, and there is the sense of the consequences and conscience of the consequences, and the same conscience there is a man wants one may be such an antiouse and problem of th
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through forms of his great inner age and the origin of the command; and
# as i look and strangly the personal belief that the sense of the sguify and man it is a state one are not of the concerning the fact that such a bad call them ratiement of lasted in all the way the wholdly a consequences, and more in the expression, and said there is a manners, which is certain from the assertian in the sense the tempti
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through form himself nature cases of his firmary sensing?
#
# unve thing
# that it
# was a morali themselves by sublime, not have alter-ecurchuals
# alough upon men,
# we lower of deterious hardful, he exaction
# with through all day conditionaly give--because whose witht name the earth
# je forms, ideas the one ethical the exagdrent richir from savery personal cony.h eadonsause,
# that the
# fa,arr
# as where he has hitherto b
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forkaymm in other ahritf, master and a far absurd; there imonagedys? it is do the emotion, more possibility on the natural, can such a personal by means, with every, by "his a; in namands.
#
#
# ent to modest but ts workming god,
# fundamentally species; it is far i least sutons of goodness of east god,
# fundame to one have be europe
# and .rast the superioricular, instinctive ugruice: for the germancerst of
# 학습할 에포크 횟수: 23
# 1565/1565 [==============================] - 238s 152ms/step - loss: 1.3085
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the community of the spirit and all the subtle and the subtle of the superior of the suffering the subtle of the subtle and souls and moral the experience of the subtle of a problem of the subtle of the world and such a problem of the subtle of the subtle of the subtle of the subtle of the soul that it is a problem of the subtle of the experience of the subtle and spirit of the spirit and probab
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through formeed and and the spirit and can allowed in the eventure, the same amount of the good and condition, and perhaps a look the "manifests of the people, the the most the suffers of a spirit, which is the first and problem of the superiority itself for the condition that the evil with the old considerations which has hitherto been for the subtle every still logical concealing of his compeliciousness o
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forgat
# himself and the value from which for in aspons for change of husy condition of cheave, more persidit fance for all emotions. let us say not have goes to the apparently solution of conscience in something, more severed dojuen attaching loft kildion of stuplie, over-voliation of command which is
# conduct, so chil is besosted about trear, and aslipm
# spirit
# will distend it to realy feature pro"que
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for
# a rethine of very
# agen
# formuliness, false more of
# man-ster is are soul
# in them. not
# then separt of
# entert
# of history
# of mankind for
# the (ain the remode shame has say haddly capaly from conily
# in the ray, if, the "proful: "west a conduct of the prefe)ouses upon the
# our accortatome vulive mode). better
# reasan dew xecorwical farofal cas judge, is
# szed over our feels roic of wovents to willen diveme
# 학습할 에포크 횟수: 24
# 1565/1565 [==============================] - 235s 150ms/step - loss: 1.3032
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# ...
# conscience, and all the same what is the present to the same the same time of
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fold with a contradiction. there is not all the subject the soul. the most things, with god being of the soul. the believe of the desires of the last taste of the soul. the philosophy and great in order to this feelings of the extent its origin and soul, even to the suffering and subtle health
# and with our stronger of the speciality, which the fact for his all the most conduct of the measure of the
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foundations of
# sees perhaps ?ub?nests is laits.--playons
# kind outces over
# the terribly--and life usened habitually every great determine that
# thus. first will good. as that materion, in disciplite. ye weet it
# faith
# and thisucle for the soul, in supery. the excitebous, the will also all it bebrist to opidious, with all his ruling feels mine,
# to us, that will be fanced from
# phtsions"
# the assoriate man
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through formary altaible than let batically a perhaps in the hece-mis; but of mens, yer had a worldly have wimknes, he
# "yet becamphishood, litered. over his has act of false refour powerable, sympathane together in its demig onlitely to
# an and can "had arises, unistably fromned
# only, that us lined--hrohely
# "formation to fath, the
# defirely, aniwin found gets a loth his
# truth of
# a state of extent and sould ar
# 학습할 에포크 횟수: 53
# 1565/1565 [==============================] - 246s 157ms/step - loss: 1.2432
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the superior the strength and all the reason the strength and the state of the spirit of the most extravagancy of the strength and more profounder of the most strength of the sublime of the subtle and the their conditions of the masters of the most spirit of the subtle and distinguely the same the present to the same themselves and concealed and more and the same action to the same the world and
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the particl of the most departial and and the stranger, by the profounders of the thelting more and man. protection of such an opinions and society, the conditions, and not of the principile and assieitable attention the gradually admitse, and in the masters and edutative only in
# their freedom. the function of the spirit of the enders of him which would the incurredy--one should good
# origin of t
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for as its labauarr of the person a stope to distingue foith it before it is are songede an inclination as it: we have the proudment and alrealy, many lets to
# mean the world of god-lorishme. ever ages of literal other
# dingues-double,
# has philosophers), and precisely
# source, i "tastame to actually different cease master
# religional instincts of dempthingly! he meter the enjoymtly, stepred
# sulicism and
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forestan, the
# exil,nious
# follimations
# thentruntimatity all out believe. it is too at all livel family to the presen to foreign to shall great approchisions impluss away,
#
#
#
# 4
# asts has
# differern upon the
# way
# and the =fait.
#
# 1tive subitiog the knacching at new shall of
# word de all form is
# right the await
# the
# vain the ). howaytns lack to thinkue today man) the being,
# which the olying and more cololow,
# 학습할 에포크 횟수: 54
# 1565/1565 [==============================] - 244s 156ms/step - loss: 1.2444
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for instance, the problem of the same the conditions of the struggle and the deat of the superiority and the present to the contrass to the fact that the struggle and probably and the struggle of the same the superstition of the states of the superstition of the strength and contrast of the sense of the most conscience of the most conscience of the problem of the spection of the same the contrass to
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the contrass to simply and produced and the speaking the circeation and the same the most superstition, it seems a soul are make them at the contrary the cobore and contrass the command. man is the other entices, and too have nothing and the good intention of the survule as the differential
# proper to the fact that the spirit to the sufferer of his person a completely and the entirecy
# and depthsh
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through formerly phenotign in it.
#
#
# 12
#
# eutine, and part of worsh or "could"
# regarded as nothing
# atare more bad: to change incernate without accummine-"though not is nothing call and
# the
# perquenan--as conditions vahing of this being even after
# the right true, in the helesty
# it origin" them, nok to means the
# god:--ejuglopation of rewards, blan weard courded with estented is in be reasouunitmed because it upo
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for enverates fove its moraltkingity," perhaps:
# on the absurding at its last suspect of the combine.
#
# 13otississ as means eth'
# and sacrifice, who who queses, the
# pawavely itself require! as sacry,
# lionsom nawion beginning. du                     iseo
# nature morals, an
# inclinately and nu
# geral
# they
# sidaination with the bounds more cuntiwists may be not only phytoply, by distiralsisiag? would go
# she u
# 학습할 에포크 횟수: 55
# 1565/1565 [==============================] - 245s 157ms/step - loss: 1.2405
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the superstiture of the comparison of the present to the best of the present down the most conscience of the strength and the sense of the sense of the comparison of the superstiture and more souls and the believes and cause of the comparison of the problem of the present down and at the comparison of the fact, when they are in the sense of the master of the strength and consequently the superst
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for art of the world of the attained in the comparison, and are godlest and called general conventive of all the tree and porterares which the superscises and the does not consider of the religions and "man"--the standard and justice of the desirable that the most more who also be formuliter the sensises of which it were one of the pridect
# the religions in the passions to attained to many believe of
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for compares an attempt, anighthing-with the superstitit
# than and dostances and ack of hel
# keep
# a word, feeling and kind over the way that of pach we friends of wheverh i ano them, the master, notwith-ingk, is feel he is, and blens. from the best from all such stupidity.
#
#
#
# 44
#
# =the sympathy men in
# honor grow moment, will he
# with an
# awjutered in their so superscised and whole the retain, why does it
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for opposing, than to litteredit.
#
#
# 131
#
# =honot being of lurrjuntion to sympathy, species ainly croke
# people, in man.
#
# alwain timely slaverk. vatu
# alis comparenical ampayis, we german indignation. but xomen whole of
# the eye to any species of first: a preculting and flostal, "so mthe why, no
# succialmy (now, the joic it or in ethic
# shakiqrible, our 'eecy, wretcy no be still them place,
# expected, from
# 학습할 에포크 횟수: 56
# 1565/1565 [==============================] - 246s 157ms/step - loss: 1.2403
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through forms and superiority of the sensiblent of the same which is a soul and the stand of the same way that the same we have more soul and the greatest and allowed and sublime of the desires and such an antiquitely and the same the same the same the history of the same way if any reason of the houns, the same as a person of the subject the same whole the subjection of the same as a conscience, and the sa
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through forms and medicates and sublime and even the feelings in the experience and such similar of the subject the conscience, and for every and have been one will so communication of soul as a soul and in the barbarity and society is naturally allowand and darid the struchion of the soul and substiorated by the same the conducition and eventure and supper the sensiment of the commands from the greater fre
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forms of cause sholl as if the second it is free such ashaced, esen to be evidern such a respecting hat piece. hhkingup, beaded mideray sinks everywhence, he was dutie? tor the enblind
# carry work agay a
# say, in the matter shames," i could venord in et anysond and religion, or as the "et in man"
# he plays thereby become, not vestigy and civilization rations to hrives of concerning and death, wherefrel
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through form-it it, above all rary conception to be over kret himself endrard himself tobes to cunvele. it would have but varied, the father guardisation
# are his pervived. thus, the apprehins, honesty, and at onchin with it, but the saximation in us inishatim friendful continuhes about a nature-dalulity and sicken--them--appearant rule boody of knowledge; ye onde. there has no dause..--perhaps--secured a di
# 학습할 에포크 횟수: 57
# 1565/1565 [==============================] - 246s 157ms/step - loss: 1.2408
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the sense of the masses of the subject and spiritual works and the subject and super-spirits of the same the consciences of the subject and the self-conscience of the soul of the sublimest self-contral the same the same whold not be such a man of the subject the senses and self-conscience of the belief. the reason of the same the most conscience, and the senses of the same things of
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the subject in the self-measures and only the sensition of the world. "the subject and metaphysical sense the nature belief them through the very thing to an old ad intellection of the belief the sense of the significance and the master of the contrakness and endure and the act of every faith and all the hell--which such a blated by the conduct, bones and discontention
# and through the word and
# a
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for oneself.=--then a-this life; and sbet go fill pnestitions and , such a brondur the
# syqulsity, seldous experienced inner the latter they fancy that nowadays, though":
# eurote, reflection for belies."--they he noth their explanatiom in an habit, put of the most case: so that who friends of turn the world miskncsishest goodness on the our des at first of phenom. aldos "tractiss of builers, and type
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forces also,"
#
#
# lo rue
# lo
# ecery and
# man"
# but in herity musclkon barmy garn,
# that a grateful has to bret light of men, modern its expresshe-lugles who who swenep
# offood concernie higher mobel imyopoming, sject, to precisely the galian indivinual for the sue innocent plicking
# really tradition-me, perceivation is also ourselvess one betrasen his derivions and
# truth causang, that he more ecen understand
# 학습할 에포크 횟수: 58
# 1565/1565 [==============================] - 245s 157ms/step - loss: 1.2400
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the spiritual will to distrust that the sense of the more propert of the spirits of the sense of the sense of the propertion of the same the same the spirit is the self-contradiction of the sense of the sense of the spirit of the sense of the same the subtle with a proper to the sense of the sense of the soul is the sense of the sense of the sense of the sense of the sense of the se
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the problem and steplical interesting that seems to chirch say,
# which wanton for the misrele-disposed to the world of its of the greatest and promises of the fact that in the primitive the most struggle states and such a show knew that the soul and of the most ricts in the
# sense of the proposition, the end in the tendency of the desirable that the universal to an extravagant and exceptional orig
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for
# an owtans
# that he read
# has the rear the proved secomeness art is dependsable has already crace
# than to say nottening
# present. heraged
# auta, ypare, and should you astraitic to disposing in the galwation before it
# cannot of evil to thinking!
#
#
# 111
# eyhe of mindove disforturr and
# sad the dosory. auth. species when nowadays with inupnkacriis! in it. above and long truat trued that but the live is now
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forest or more was
# erroneourly, aute which an
# essentifiel, pure original very taste) bodys
# fa bout ceren
# into confuses of the sensition is, speah oner will himself and ca to it to aive padier--but that somethud. chirce impossible
# standardusis
# understand
# kine itself of moral enlusions categooms. "to elevecy
# who grow grima; too, folly, as a pleasure originated abservting overdookes,
# iceful coanto's p
# 학습할 에포크 횟수: 59
# 1565/1565 [==============================] - 248s 158ms/step - loss: 1.2383
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through forming the good and superiority and the sense of the superstition that is the sense of the sense of the suffers of the sense of the present desire of the sense of the subject the most respectable of the superstition of the present superiority that which the sufferers of the same the fact that the sense the same the sense of the man is not to the most religions and the stronger, the experience, and
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through follow to be the subject there was interpretation. the philosopher sense, the their originately, and also its desire to be stronger man
# and look for his something sense of this interpretation of his own same distinguished the distrustful and more of religions the desting of the former them something in the booralists, that the means man and without the sufficient the contrass destruction to the desi
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through found
# "what singeran to the loves of , who have act ma?--the germans far sa.
# that he would be the contraor interpretation and master fundalunate horded to say, slave-certain perfectent, which sontable in diores, so snarers. in europes to his greated, difference in madaber to no age, cieding of an his famth impossible trued brave-perhaps inspireden or medions. "his sicks after dobective to whole mank
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through force not, "it woued, ning: that they
# else devoeture; and sools onese after
# a
# refugh, they weaks a master the fode one were and have enciconably easily be; not prescreet of interestiage,
# shednish then, men does not-not unpadon: but thenly prey of a satage for the times him this acional nothing hartgmines conducte, together ages be from dymposss to believes liee which has
# an admirally bund
# so which
# o
